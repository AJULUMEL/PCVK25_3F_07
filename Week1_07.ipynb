# %% [markdown]
# <a href="https://colab.research.google.com/github/AJULUMEL/PCVK25_3F_07/blob/main/Week1_07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PRAKTIKUM D1

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow  # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://avatars.githubusercontent.com/u/144210127?s=400&u=87e8ee41e8eb045e8975fdfc18016510eda2ba0e&v=4"]

for url in urls:
    image = io.imread(url)
    image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
    image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
    final_frame = cv.hconcat([image, image_2])
    cv2_imshow(final_frame)
    print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=400x200>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ", tinggi, " x ", lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  200  x  200
# <PIL.Image.Image image mode=RGB size=200x200>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range(lebar):
    image_3[int((tinggi)/2), y] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>

# %% [markdown]
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan
# menggunakan Google Colab?
#
# - Gratis dan mudah diakses
# - Library sudah terinstall
# - Tidak perlu setup Python lokal
# - bisa connect dengan github dan drive
#
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke
# delapan? Apakah semua library tersebut harus digunakan dalam praktikum
# sesi ini?
#
# - NumPy & Pandas: Diimpor tapi tidak secara langsung digunakan dalam kode yang ditampilkan.
# - OpenCV (cv2): Digunakan untuk memproses gambar (baca, ubah warna, ubah ukuran, gabung gambar).
# - cv2_imshow: Digunakan khusus di Colab untuk menampilkan gambar OpenCV.
# - Skimage (io): Digunakan untuk membaca gambar dari URL.
# - Skimage (transform) & PIL & Matplotlib: Diimpor tapi tidak secara langsung digunakan dalam kode yang ditampilkan.
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :
#
# Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak
# dilakukan?
#
# **untuk me resize gambar menjadi ukuran setengahnya**
#
# 4. Perhatikan potongan kode progam berikut :
#
# Apakah kegunaan kode [255,255,255] ? Jelaskan!
#
# **untuk menampilkan warna putih karena semakin besar bitnya akan menjadi warna putih**
#
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun
# rendah!
# - Pixel = unit terkecil gambar
# - Resolusi = jumlah pixel (lebar × tinggi)
# - Resolusi tinggi = lebih banyak pixel = gambar lebih tajam
# - Resolusi rendah = sedikit pixel = gambar kurang tajam

# %% [markdown]
# TUGAS PRAKTIKUM D2

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for x in range(tinggi):
    image_3[x, int(lebar/2)] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for i in range(min(tinggi, lebar)):
    image_3[i, i] = [255, 255, 255]

for i in range(min(tinggi, lebar)):
    image_3[i, lebar - 1 - i] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

panjang_garis = lebar // 2
start_x = (lebar - panjang_garis) // 2
end_x = start_x + panjang_garis
y_tengah = int(tinggi / 2)

for x in range(start_x, end_x):
    image_3[y_tengah, x] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

x_awal = 50
y_awal = 60
kotak_lebar = 100
kotak_tinggi = 80

for y in range(y_awal, y_awal + kotak_tinggi):
    for x in range(x_awal, x_awal + kotak_lebar):
        image_3[y, x] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>
